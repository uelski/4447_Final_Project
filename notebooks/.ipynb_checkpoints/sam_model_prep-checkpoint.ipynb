# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Model Preparation
#
# - take processed csv files and continue feature engineering to output model-ready data

# %%
# setup
df = pd.read_csv('../data/processed/neighborhood_complete.csv')

# %%
# list columns for reference for each new csv file to be used in models
list(df.columns)
# Out:
# ['neighborhood',
#  'program_count',
#  'total_cime_incidents',
#  'theft_from_motor_vehicle',
#  'auto_theft',
#  'public_disorder',
#  'larceny',
#  'all_other_crimes',
#  'burglary',
#  'drug_alcohol',
#  'other_crimes_against_persons',
#  'aggravated_assault',
#  'robbery',
#  'white_collar_crime',
#  'arson',
#  'murder',
#  'area_m2',
#  'OBJECTID_1',
#  'GLOBALID',
#  'avgsocioeconscore',
#  'avgAccessToCareScore',
#  'avgMobidityScore',
#  'mortalityscore',
#  'avgBuiltEnvScore',
#  'avgOverallEquityScore',
#  'Shape__Area_x',
#  'Shape__Length_x',
#  'OBJECTID',
#  'Neighborhood Name',
#  'Total Population All',
#  'Hispanic or Latino',
#  'White',
#  'Black',
#  'Native American',
#  'Asian',
#  'Hawaiian/Pacific Islander',
#  'Other Race',
#  'Two or More',
#  'Percent Hispanic',
#  'Percent White',
#  'Percent Black',
#  'Percent Native American',
#  'Percent Asian',
#  'Percent Hawaiian/Pacific Islander',
#  'Percent Other Race',
#  'Percent Two or More Races',
# ...

# %% [markdown]
# ## Shared Data
#
# - feature engineering for both regression and classification models

# %%
# dropping more columns
clean_df = df[['neighborhood', 'program_count', 'total_cime_incidents', 'theft_from_motor_vehicle', 'auto_theft', 'public_disorder', 'larceny', 'all_other_crimes', 'burglary', 'drug_alcohol', 'other_crimes_against_persons', 'aggravated_assault', 'robbery', 'white_collar_crime', 'arson', 'murder', 'avgsocioeconscore', 'avgAccessToCareScore', 'avgMobidityScore', 'mortalityscore', 'avgBuiltEnvScore', 'avgOverallEquityScore', 'Total Population All', 'Percent Hispanic', 'Percent White', 'Percent Black', 'Percent Native American', 'Percent Asian', 'Percent Hawaiian/Pacific Islander', 'Percent Other Race', 'Percent Two or More Races', 'Median Household Income', 'Per Capita Income', 'Median Home Value', 'Percent Living in Poverty', 'Percent Families in Poverty', 'Shape__Area_y', 'Less Than HS Diploma','HS Graduate or Equivalent', 'Some College or AA', 'Bachelors or Higher', 'area_m2', 'Total Population Over 25']].copy()

# %%
clean_df.dtypes
# Out:
# neighborhood                          object
# program_count                        float64
# total_cime_incidents                   int64
# theft_from_motor_vehicle               int64
# auto_theft                             int64
# public_disorder                        int64
# larceny                                int64
# all_other_crimes                       int64
# burglary                               int64
# drug_alcohol                           int64
# other_crimes_against_persons           int64
# aggravated_assault                     int64
# robbery                                int64
# white_collar_crime                     int64
# arson                                  int64
# murder                                 int64
# avgsocioeconscore                    float64
# avgAccessToCareScore                 float64
# avgMobidityScore                     float64
# mortalityscore                         int64
# avgBuiltEnvScore                     float64
# ...

# %% [markdown]
# ### Calculate total crime and categorized crime counts per 1000 residents for each neighborhood

# %%
clean_df["crime_per1000"] = (clean_df['total_cime_incidents'] / clean_df['Total Population All']) * 1000
clean_df["theft_mv_per1000"] = (clean_df['theft_from_motor_vehicle'] / clean_df['Total Population All']) * 1000
clean_df["auto_theft_per1000"] = (clean_df['auto_theft'] / clean_df['Total Population All']) * 1000
clean_df["disorder_per1000"] = (clean_df['public_disorder'] / clean_df['Total Population All']) * 1000
clean_df["larceny_per1000"] = (clean_df['larceny'] / clean_df['Total Population All']) * 1000
clean_df["other_per1000"] = (clean_df['all_other_crimes'] / clean_df['Total Population All']) * 1000
clean_df["burglary_per1000"] = (clean_df['burglary'] / clean_df['Total Population All']) * 1000
clean_df["drug_alcohol_per1000"] = (clean_df['drug_alcohol'] / clean_df['Total Population All']) * 1000
clean_df["crime_against_persons_per1000"] = (clean_df['other_crimes_against_persons'] / clean_df['Total Population All']) * 1000
clean_df["assult_per1000"] = (clean_df['aggravated_assault'] / clean_df['Total Population All']) * 1000
clean_df["robbery_per1000"] = (clean_df['robbery'] / clean_df['Total Population All']) * 1000
clean_df["white_collar_per1000"] = (clean_df['white_collar_crime'] / clean_df['Total Population All']) * 1000
clean_df["arson_per1000"] = (clean_df['arson'] / clean_df['Total Population All']) * 1000
clean_df["murder_per1000"] = (clean_df['murder'] / clean_df['Total Population All']) * 1000
clean_df["program_count_per1000"] = (clean_df['program_count'] / clean_df['Total Population All']) * 1000

# %%
clean_df.head()
# Out:
#   neighborhood  program_count  total_cime_incidents  theft_from_motor_vehicle  \
# 0  Athmar Park          500.0                  3429                       527
# 1      Auraria           13.0                  2815                       249
# 2        Baker          341.0                  6489                      1087
# 3       Barnum          437.0                  2712                       280
# 4  Barnum West          233.0                  1609                       228
#
#    auto_theft  public_disorder  larceny  all_other_crimes  burglary  \
# 0         540              511      343               529       294
# 1         159              387      379              1173        69
# 2         875             1058     1289               480       565
# 3         338              382      198               732       182
# 4         265              208      106               418       100
#
#    drug_alcohol  ...  other_per1000  burglary_per1000  drug_alcohol_per1000  \
# ...

# %% [markdown]
# ### Calculate populate density
#
# - based on neighborhood Total Population All / area_km2

# %%
clean_df["area_km2"] = clean_df["area_m2"] / 1e6

# %%
clean_df["population_density"] = clean_df["Total Population All"] / clean_df["area_km2"]

# %%
clean_df.iloc[0]["population_density"]
# Out:
# 2213.0009021727687

# %% [markdown]
# ### Calculate education levels

# %%
clean_df["percent_less_hs"] = (clean_df["Less Than HS Diploma"] / clean_df["Total Population Over 25"]) * 100
clean_df["percent_at_hs"] = (clean_df["HS Graduate or Equivalent"] / clean_df["Total Population Over 25"]) * 100
clean_df["percent_some_college"] = (clean_df["Some College or AA"] / clean_df["Total Population Over 25"]) * 100
clean_df["percent_bachelors"] = (clean_df["Bachelors or Higher"] / clean_df["Total Population Over 25"]) * 100

# %%
clean_df.iloc[2]["percent_less_hs"]
# Out:
# 6.148007590132827

# %%
clean_df.iloc[2]["percent_at_hs"]
# Out:
# 8.72865275142315

# %%
clean_df.iloc[2]["percent_some_college"]
# Out:
# 12.656546489563567

# %%
clean_df.iloc[2]["percent_bachelors"]
# Out:
# 72.46679316888046

# %% [markdown]
# ## Create new dataframes from original

# %%
list(clean_df.columns)
# Out:
# ['neighborhood',
#  'program_count',
#  'total_cime_incidents',
#  'theft_from_motor_vehicle',
#  'auto_theft',
#  'public_disorder',
#  'larceny',
#  'all_other_crimes',
#  'burglary',
#  'drug_alcohol',
#  'other_crimes_against_persons',
#  'aggravated_assault',
#  'robbery',
#  'white_collar_crime',
#  'arson',
#  'murder',
#  'avgsocioeconscore',
#  'avgAccessToCareScore',
#  'avgMobidityScore',
#  'mortalityscore',
#  'avgBuiltEnvScore',
#  'avgOverallEquityScore',
#  'Total Population All',
#  'Percent Hispanic',
#  'Percent White',
#  'Percent Black',
#  'Percent Native American',
#  'Percent Asian',
#  'Percent Hawaiian/Pacific Islander',
#  'Percent Other Race',
#  'Percent Two or More Races',
#  'Median Household Income',
#  'Per Capita Income',
#  'Median Home Value',
#  'Percent Living in Poverty',
#  'Percent Families in Poverty',
#  'Shape__Area_y',
#  'Less Than HS Diploma',
#  'HS Graduate or Equivalent',
#  'Some College or AA',
#  'Bachelors or Higher',
# ...

# %%
# crime data
crime_clean_df = clean_df[['neighborhood', 'avgsocioeconscore', 'avgAccessToCareScore', 'avgMobidityScore', 'mortalityscore', 'avgBuiltEnvScore', 'avgOverallEquityScore', 'Percent Hispanic', 'Percent White', 'Percent Black', 'Percent Native American', 'Percent Asian', 'Percent Hawaiian/Pacific Islander', 'Percent Other Race', 'Percent Two or More Races', 'Median Household Income', 'Per Capita Income', 'Median Home Value', 'Percent Living in Poverty', 'Percent Families in Poverty', 'population_density',
 'percent_less_hs',
 'percent_at_hs',
 'percent_some_college',
 'percent_bachelors','crime_per1000',
 'theft_mv_per1000',
 'auto_theft_per1000',
 'disorder_per1000',
 'larceny_per1000',
 'other_per1000',
 'burglary_per1000',
 'drug_alcohol_per1000',
 'crime_against_persons_per1000',
 'assult_per1000',
 'robbery_per1000',
 'white_collar_per1000',
 'arson_per1000',
 'murder_per1000',
 'program_count_per1000']].copy()

# %%
list(crime_clean_df)
# Out:
# ['neighborhood',
#  'avgsocioeconscore',
#  'avgAccessToCareScore',
#  'avgMobidityScore',
#  'mortalityscore',
#  'avgBuiltEnvScore',
#  'avgOverallEquityScore',
#  'Percent Hispanic',
#  'Percent White',
#  'Percent Black',
#  'Percent Native American',
#  'Percent Asian',
#  'Percent Hawaiian/Pacific Islander',
#  'Percent Other Race',
#  'Percent Two or More Races',
#  'Median Household Income',
#  'Per Capita Income',
#  'Median Home Value',
#  'Percent Living in Poverty',
#  'Percent Families in Poverty',
#  'population_density',
#  'percent_less_hs',
#  'percent_at_hs',
#  'percent_some_college',
#  'percent_bachelors',
#  'crime_per1000',
#  'theft_mv_per1000',
#  'auto_theft_per1000',
#  'disorder_per1000',
#  'larceny_per1000',
#  'other_per1000',
#  'burglary_per1000',
#  'drug_alcohol_per1000',
#  'crime_against_persons_per1000',
#  'assult_per1000',
#  'robbery_per1000',
#  'white_collar_per1000',
#  'arson_per1000',
#  'murder_per1000',
#  'program_count_per1000']

# %%
equity_clean_df = clean_df[['neighborhood', 'avgOverallEquityScore', 'Percent Hispanic', 'Percent White', 'Percent Black', 'Percent Native American', 'Percent Asian', 'Percent Hawaiian/Pacific Islander', 'Percent Other Race', 'Percent Two or More Races', 'Median Household Income', 'Per Capita Income', 'Median Home Value', 'Percent Living in Poverty', 'Percent Families in Poverty', 'population_density',
 'percent_less_hs',
 'percent_at_hs',
 'percent_some_college',
 'percent_bachelors', 'program_count_per1000', 'crime_per1000']].copy()

# %%
list(equity_clean_df.columns)
# Out:
# ['neighborhood',
#  'avgOverallEquityScore',
#  'Percent Hispanic',
#  'Percent White',
#  'Percent Black',
#  'Percent Native American',
#  'Percent Asian',
#  'Percent Hawaiian/Pacific Islander',
#  'Percent Other Race',
#  'Percent Two or More Races',
#  'Median Household Income',
#  'Per Capita Income',
#  'Median Home Value',
#  'Percent Living in Poverty',
#  'Percent Families in Poverty',
#  'population_density',
#  'percent_less_hs',
#  'percent_at_hs',
#  'percent_some_college',
#  'percent_bachelors',
#  'program_count_per1000',
#  'crime_per1000']

# %% [markdown]
# ## Export to new csv files

# %%
# create new csv with complete clean data
clean_df.to_csv("../data/processed/neighborhood_models.csv", index=False)

# create csv with crime data
crime_clean_df.to_csv("../data/processed/neighborhood_crime_counts.csv", index=False)

# create csv with equity data
equity_clean_df.to_csv("../data/processed/neighborhood_equity_model.csv", index=False)
