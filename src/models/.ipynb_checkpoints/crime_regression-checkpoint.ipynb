# %%
import pandas as pd
import numpy as np 
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import r2_score, root_mean_squared_error
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

# %%
# setup and feature engineering
df = pd.read_csv('../../data/processed/neighborhood_crime_counts.csv')

# set neighborhood as index so removed from feature columns
df.set_index("neighborhood", inplace=True)

# select feature columns
feature_cols = ['avgsocioeconscore', 'avgAccessToCareScore', 'avgMobidityScore', 'mortalityscore', 'avgBuiltEnvScore', 'avgOverallEquityScore', 
                'population_density', 'Percent White', 'Median Household Income', 'Per Capita Income', 
                'program_count_per1000', 'Percent Black','Percent Native American', 'Percent Hispanic', 'Median Home Value',
                'Percent Asian','Percent Hawaiian/Pacific Islander','Percent Other Race','Percent Two or More Races', 'Percent Living in Poverty', 
               'percent_less_hs', 'percent_at_hs', 'percent_some_college','percent_bachelors']
X = df[feature_cols]

# target column - unscaled
target_col = 'crime_per1000'
y = df[target_col].values

# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)

# scale
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# scale full X
scaler_full = StandardScaler()
X_scaled = scaler_full.fit_transform(X)

# %%
df[target_col].describe()
# Out:
# count      78.000000
# mean      683.871890
# std       968.995353
# min        97.443609
# 25%       309.324489
# 50%       411.934134
# 75%       626.925245
# max      7270.095073
# Name: crime_per1000, dtype: float64

# %%
crime_quantile = int(df[target_col].quantile(.99))
crime_quantile
# Out:
# 4695

# %% [markdown]
# ## Basic Linear Regression without Regularization

# %%
lr_model = LinearRegression()
lr_model.fit(X_scaled, y)

# coefficients
lr_coef_df = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": lr_model.coef_
}).sort_values(by="Coefficient", key=abs, ascending=False)
print(lr_coef_df)

# model performance
lr_r2 = r2_score(y, lr_model.predict(X_scaled))
lr_rmse = root_mean_squared_error(y, lr_model.predict(X_scaled))
# Out:
#                               Feature   Coefficient
# 7                       Percent White -1.886579e+11
# 13                   Percent Hispanic -1.802118e+11
# 11                      Percent Black -7.433361e+10
# 15                      Percent Asian -1.918350e+10
# 18          Percent Two or More Races -1.831452e+10
# 12            Percent Native American -4.960109e+09
# 16  Percent Hawaiian/Pacific Islander -3.438999e+09
# 17                 Percent Other Race -3.153508e+09
# 5               avgOverallEquityScore -1.469007e+09
# 3                      mortalityscore  5.039313e+08
# 0                   avgsocioeconscore  4.635356e+08
# 1                avgAccessToCareScore  4.410322e+08
# 4                    avgBuiltEnvScore  3.675235e+08
# 2                    avgMobidityScore  2.735371e+08
# 23                  percent_bachelors  3.492135e+04
# 20                    percent_less_hs  1.700579e+04
# 21                      percent_at_hs  1.442872e+04
# 22               percent_some_college  1.059705e+04
# 10              program_count_per1000  1.709727e+02
# 19          Percent Living in Poverty  1.412352e+02
# 14                  Median Home Value  7.817912e+01
# 8             Median Household Income  6.409229e+01
# 9                   Per Capita Income -6.252644e+01
# 6                  population_density -9.312700e+00

# %%
print(lr_r2)
# Out:
# 0.4570339512246858

# %%
print(lr_rmse)
# Out:
# 709.4243527939299

# %% [markdown]
# ## Linear Regression with L1 Regularization

# %%
lasso = Lasso(alpha=0.1)
lasso.fit(X_scaled, y)

# coefficients
lasso_coef_df = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": lasso.coef_
}).sort_values(by="Coefficient", key=abs, ascending=False)
print(lasso_coef_df)

# model performance
lasso_r2 = r2_score(y, lasso.predict(X_scaled))
lasso_rmse = root_mean_squared_error(y, lasso.predict(X_scaled))
# Out:
#                               Feature  Coefficient
# 21                      percent_at_hs  -704.651488
# 7                       Percent White  -558.056487
# 1                avgAccessToCareScore  -520.335885
# 0                   avgsocioeconscore   344.109758
# 2                    avgMobidityScore  -326.716609
# 3                      mortalityscore   305.702738
# 11                      Percent Black   218.594515
# 22               percent_some_college   160.005359
# 20                    percent_less_hs  -154.973608
# 17                 Percent Other Race  -152.950365
# 19          Percent Living in Poverty   151.628698
# 4                    avgBuiltEnvScore   147.423183
# 10              program_count_per1000   138.101735
# 8             Median Household Income   127.959959
# 9                   Per Capita Income  -104.246531
# 12            Percent Native American   100.756941
# 18          Percent Two or More Races    97.871214
# 23                  percent_bachelors   -94.132882
# 16  Percent Hawaiian/Pacific Islander    89.431994
# 14                  Median Home Value    58.921226
# 13                   Percent Hispanic   -27.993461
# 5               avgOverallEquityScore    11.801435
# 6                  population_density   -10.937567
# 15                      Percent Asian     3.198832
# /Users/uelski/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.623e+06, tolerance: 7.230e+03
#   model = cd_fast.enet_coordinate_descent(

# %%
print(lasso_r2)
# Out:
# 0.43250123056055145

# %%
print(lasso_rmse)
# Out:
# 725.2741813979987

# %% [markdown]
# ## Linear Regression with L2 Regularization

# %%
ridge = Ridge(alpha=0.1)
ridge.fit(X_scaled, y)

# coefficients
ridge_coef_df = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": ridge.coef_
}).sort_values(by="Coefficient", key=abs, ascending=False)
print(ridge_coef_df)

# model performance
ridge_r2 = r2_score(y, ridge.predict(X_scaled))
ridge_rmse = root_mean_squared_error(y, ridge.predict(X))
# Out:
#                               Feature  Coefficient
# 21                      percent_at_hs  -571.370961
# 1                avgAccessToCareScore  -520.005605
# 0                   avgsocioeconscore   329.283884
# 2                    avgMobidityScore  -324.801134
# 7                       Percent White  -315.871909
# 11                      Percent Black   310.690783
# 3                      mortalityscore   301.055571
# 22               percent_some_college   241.184308
# 13                   Percent Hispanic   185.396607
# 23                  percent_bachelors   182.430859
# 17                 Percent Other Race  -149.245905
# 19          Percent Living in Poverty   147.229679
# 4                    avgBuiltEnvScore   145.719576
# 10              program_count_per1000   138.314073
# 8             Median Household Income   128.118462
# 18          Percent Two or More Races   120.518601
# 9                   Per Capita Income  -106.735214
# 12            Percent Native American   105.929812
# 16  Percent Hawaiian/Pacific Islander    93.367834
# 14                  Median Home Value    58.634939
# 5               avgOverallEquityScore    27.026701
# 15                      Percent Asian    26.230635
# 20                    percent_less_hs   -14.983099
# 6                  population_density   -10.820100
# /Users/uelski/anaconda3/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but Ridge was fitted without feature names
#   warnings.warn(

# %%
print(ridge_r2)
# Out:
# 0.43247332346473877

# %%
print(ridge_rmse)
# Out:
# 37451668.184692316

# %% [markdown]
# ## Linear Regression with Elasticnet Regularization

# %%
elastic = ElasticNet(alpha=0.1, l1_ratio=0.1)
elastic.fit(X_scaled, y)

# coefficients
elastic_coef_df = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": elastic.coef_
}).sort_values(by="Coefficient", key=abs, ascending=False)
print(elastic_coef_df)

# model performance
elastic_r2 = r2_score(y, elastic.predict(X_scaled))
elastic_rmse = root_mean_squared_error(y, elastic.predict(X))
# Out:
#                               Feature  Coefficient
# 1                avgAccessToCareScore  -308.837879
# 11                      Percent Black   285.794880
# 21                      percent_at_hs  -255.242885
# 3                      mortalityscore   246.596606
# 4                    avgBuiltEnvScore   174.382790
# 2                    avgMobidityScore  -163.146187
# 22               percent_some_college   159.627899
# 7                       Percent White  -150.088253
# 17                 Percent Other Race  -129.770237
# 10              program_count_per1000   117.518419
# 18          Percent Two or More Races   104.136990
# 9                   Per Capita Income   -94.934968
# 0                   avgsocioeconscore    89.662693
# 23                  percent_bachelors    89.215973
# 12            Percent Native American    73.653153
# 8             Median Household Income    66.428261
# 16  Percent Hawaiian/Pacific Islander    58.163087
# 19          Percent Living in Poverty    54.694352
# 20                    percent_less_hs   -54.084148
# 6                  population_density   -40.485341
# 5               avgOverallEquityScore    33.348967
# 13                   Percent Hispanic    25.583766
# 15                      Percent Asian    20.090773
# 14                  Median Home Value     7.740407
# /Users/uelski/anaconda3/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but ElasticNet was fitted without feature names
#   warnings.warn(

# %%
print(elastic_r2)
# Out:
# 0.4046332460209774

# %%
print(elastic_rmse)
# Out:
# 4857109.109650765
